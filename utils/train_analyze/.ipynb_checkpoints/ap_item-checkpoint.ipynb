# %%
import numpy as np

# %%
names = np.load('name.npy')
labels = np.load('label.npy')
print names.shape
print labels.shape
# Out:
# (25882,)
# (25882,)

# %%
print names[:2]
print labels[:2]
# Out:
# ['img/WOMEN/Blouses_Shirts/id_00003498/01_7_additional.jpg'
#  'img/WOMEN/Shorts/id_00005386/04_3_back.jpg']
# [1218  322]

# %%
# cluster to NameSets
vector={}
for i,n in enumerate(labels):
    if str(n) not in vector:
        vector[str(n)]=[]
    vector[str(n)].append(names[i])
cluster = vector.keys()
print len(cluster)
# Out:
# 1310

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
base_dir = "/home/zhangxs/data/In-shop-IR/"

# %%
cls = np.random.choice(cluster)
print 'current idx: ',cls
rst = vector[cls]
print 'num of cluster: ',len(rst)
rst[:5]
# Out:
# current idx:  51
# num of cluster:  26
# ['img/WOMEN/Tees_Tanks/id_00004386/05_1_front.jpg',
#  'img/WOMEN/Tees_Tanks/id_00003710/02_7_additional.jpg',
#  'img/WOMEN/Tees_Tanks/id_00004386/06_3_back.jpg',
#  'img/WOMEN/Dresses/id_00005448/07_1_front.jpg',
#  'img/WOMEN/Tees_Tanks/id_00005245/01_3_back.jpg']

# %%
plt.figure(figsize=(12,12))
pics = np.random.choice(vector[cls],9)
for i,p in enumerate(pics):
    plt.subplot(3,3,i+1)
    img = Image.open(base_dir+p).resize((75,75))
    plt.imshow(img)
    plt.axis('off')
